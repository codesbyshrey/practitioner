# %%
1+1
# Out:
# 2

# %%
import urllib.request #this one lets you connect to the website
import re             #extracting patterns made easier...
import pandas as pd   #for all things data wrangling
from bs4 import BeautifulSoup #Soup is for scraping
import shutil         #Utilities

# %%
#the basic unit of code is a function
# our aim is to scrape for the image and assign the url as jpg

def scrape_4_an_image(web_page_img, file_path, file_name):
    full_path = file_path + file_name + '.jpg'
    urllib.request.urlretrieve(web_page_img, full_path)

# %%
# before we say action, a good idea to know where we are

path = !pwd
path_s = path[0]+'/Workshop/'
path_s

# %%
#start and action

web_page_img = input('URl to image goes here')
#https://content.fortune.com/wp-content/uploads/2022/11/GettyImages-1425749502-e1668005354764.jpg?w=1440&q=75

file_name = input('Name of image file goes here')
#TaylorSwift

scrape_4_an_image(web_page_img, path_s, file_name)
print ("It's all done")
